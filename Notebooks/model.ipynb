# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import joblib
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
  # 1. Load processed data
X_train = pd.read_csv('/content/drive/MyDrive/Telecom churn prediction/data/processed/X_train.csv')
y_train = pd.read_csv('/content/drive/MyDrive/Telecom churn prediction/data/processed/y_train.csv').values.ravel()
X_test = pd.read_csv('/content/drive/MyDrive/Telecom churn prediction/data/processed/X_test.csv')
y_test = pd.read_csv('/content/drive/MyDrive/Telecom churn prediction/data/processed/y_test.csv').values.ravel()

# %%
# 2. Identify feature types
numerical_features = [col for col in ['age', 'estimated_salary', 'calls_made', 'sms_sent', 'data_used'] if col in X_train.columns]
categorical_features = [col for col in X_train.columns if col not in numerical_features]


# 3. Build preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ]
)

# %%
# 4. Build full pipeline
clf = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=100, max_depth=15, random_state=42))
])

# %%
# 5. Train
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'estimated_salary',
#                                                    'calls_made', 'sms_sent',
#                                                    'data_used']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['pincode',
#                                                    'date_of_registration',
#                                                    'num_dependents',
#                                                    'telecom_partner_BSNL',
#                                                    'telecom_partner_Reliance '
#                                                    'Jio',
# ...

# %%
# 7. Save model and preprocessor
joblib.dump(clf.named_steps['classifier'], '/content/drive/MyDrive/Telecom churn prediction/models/random_forest_classifier.pkl')
joblib.dump(clf.named_steps['preprocessor'], '/content/drive/MyDrive/Telecom churn prediction/models/preprocessor.joblib')
# Out:
# ['/content/drive/MyDrive/Telecom churn prediction/models/preprocessor.joblib']

# %%
from sklearn.metrics import classification_report
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89     58412
#            1       0.00      0.00      0.00     14654
#
#     accuracy                           0.80     73066
#    macro avg       0.40      0.50      0.44     73066
# weighted avg       0.64      0.80      0.71     73066
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# !pip install -q streamlit
# !npm install -q localtunnel
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 102.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 147.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.8 MB/s eta 0:00:00
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# added 22 packages in 2s
# ⠏
# ⠏3 packages are looking for funding
# ⠏  run `npm fund` for details
# ⠏

# %%
# %cd /content/drive/MyDrive/Telecom churn prediction/dashboard
# Out:
# /content/drive/MyDrive/Telecom churn prediction/dashboard

# %%
# !pip install pyngrok streamlit --quiet
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼
# added 22 packages in 708ms
# ⠼
# ⠼3 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼

# %%
from pyngrok import ngrok
print("pyngronk is working")
# Out:
# pyngronk is working

# %%
# import streamlit as st
# import pandas as pd
# import joblib
# import datetime

# # Load pre-trained model and preprocessor
# model = joblib.load("models/random_forest_classifier.pkl")
# preprocessor = joblib.load("models/preprocessor.joblib")

# st.title("📊 Telecom Churn Prediction Dashboard")
# st.markdown("Predict if a customer is likely to churn based on their information.")

# # Streamlit form inputs
# st.header("Enter Customer Details")

# # Input widgets
# age = st.slider("Age", 18, 100, 30)
# gender = st.selectbox("Gender", ["Male", "Female"])
# pincode = st.text_input("Pincode", "110001")
# estimated_salary = st.number_input("Estimated Salary", min_value=0.0, step=1000.0)
# calls_made = st.number_input("Calls Made Last Month", min_value=0, step=1)
# sms_sent = st.number_input("SMS Sent Last Month", min_value=0, step=1)
# data_used = st.number_input("Data Used (in GB)", min_value=0.0, step=0.1)
# city = st.selectbox("City", ["New Delhi", "Mumbai", "Bangalore", "Hyderabad", "Other"])
# telecom_partner = st.selectbox("Telecom Partner", ["Jio", "Airtel", "Vi", "BSNL"])
# num_dependents = st.number_input("Number of Dependents", min_value=0, step=1)
# date_of_registration = st.date_input("Date of Registration", datetime.date(2020, 1, 1))

# # Submit button
# if st.button("Predict Churn"):
#     # Prepare input data
#     input_df = pd.DataFrame([{
#         'age': age,
#         'gender': gender,
#         'pincode': pincode,
#         'estimated_salary': estimated_salary,
#         'calls_made': calls_made,
#         'sms_sent': sms_sent,
#         'data_used': data_used,
#         'city': city,
#         'telecom_partner': telecom_partner,
#         'num_dependents': num_dependents,
#         'date_of_registration': date_of_registration
#     }])

#     # Preprocess input
#     processed_input = preprocessor.transform(input_df)

#     # Make prediction
#     prediction = model.predict(processed_input)[0]
#     prediction_proba = model.predict_proba(processed_input)[0][1]

#     # Show result
#     st.subheader("Prediction Result")
#     if prediction == 1:
#         st.error(f"⚠️ This customer is likely to churn. (Probability: {prediction_proba:.2f})")
#     else:
#         st.success(f"✅ This customer is likely to stay. (Probability: {prediction_proba:.2f})")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-43-766238564.py in <cell line: 0>()
#       5
#       6 # Load pre-trained model and preprocessor
# ----> 7 model = joblib.load("models/random_forest_classifier.pkl")
#       8 preprocessor = joblib.load("models/preprocessor.joblib")
#       9
#
# /usr/local/lib/python3.11/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode, ensure_native_byte_order)
#     733             obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734     else:
# --> 735         with open(filename, "rb") as f:
#     736             with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737                 fobj,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/random_forest_classifier.pkl'

# %%
expected_columns = list(preprocessor.feature_names_in_)
print(expected_columns)
# Out:
# ['age', 'pincode', 'date_of_registration', 'num_dependents', 'estimated_salary', 'calls_made', 'sms_sent', 'data_used', 'telecom_partner_BSNL', 'telecom_partner_Reliance Jio', 'telecom_partner_Vodafone', 'gender_M', 'state_Arunachal Pradesh', 'state_Assam', 'state_Bihar', 'state_Chhattisgarh', 'state_Goa', 'state_Gujarat', 'state_Haryana', 'state_Himachal Pradesh', 'state_Jharkhand', 'state_Karnataka', 'state_Kerala', 'state_Madhya Pradesh', 'state_Maharashtra', 'state_Manipur', 'state_Meghalaya', 'state_Mizoram', 'state_Nagaland', 'state_Odisha', 'state_Punjab', 'state_Rajasthan', 'state_Sikkim', 'state_Tamil Nadu', 'state_Telangana', 'state_Tripura', 'state_Uttar Pradesh', 'state_Uttarakhand', 'state_West Bengal', 'city_Chennai', 'city_Delhi', 'city_Hyderabad', 'city_Kolkata', 'city_Mumbai']

# %%
# !pkill -f ngrok

# %%
# %%writefile run_streamlit.py
import subprocess
from pyngrok import ngrok
import time

# Kill any existing tunnels (prevention)
ngrok.kill()

# Set port
port = 8501

# Start ngrok tunnel
public_url = ngrok.connect(port)
print("🔗 Streamlit App Public URL:", public_url)

# Wait for tunnel to settle
time.sleep(2)

# Start Streamlit
subprocess.run(["streamlit", "run", "/content/drive/MyDrive/Telecom churn prediction/dashboard/app.py", "--server.port", str(port)])
# Out:
# Overwriting run_streamlit.py

# %%
# !python3 run_streamlit.py
# Out:
# 🔗 Streamlit App Public URL: NgrokTunnel: "https://98be2d0ae059.ngrok-free.app" -> "http://localhost:8501"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.194.219.129:8501
#
#   Stopping...
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
# !ngrok config add-authtoken 30NFlTX5Av1hPpMzxkqNMd0uWVI_7CUdUH89Kb1XAyrofy5rz
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# %cd "/content/drive/MyDrive/Telecom churn prediction"
# Out:
# /content/drive/MyDrive/Telecom churn prediction

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Telecom churn prediction/dashboard/.git/

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/Yashgupta-01/telecom-churn-prediction.git
# Out:
# error: remote origin already exists.

# %%
# !git remote set-url origin https://Yashgupta-01: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@github.com/Yashgupta-01/telecom-churn-prediction.git

# %%
# !echo ".ipynb_checkpoints/" >> .gitignore
# !echo "*.pyc" >> .gitignore
# !echo "__pycache__/" >> .gitignore
# !echo "*.joblib" >> .gitignore
# !echo "*.pkl" >> .gitignore

# %%
# !git add .

# %%
# !git config --global user.name "Yashgupta-01"
# !git config --global user.email "yashxmgupta@gmail.com"

# %%
# !git commit -m "Initial commit - telecom churn prediction project"
# Out:
# [master e22eb27] Initial commit - telecom churn prediction project
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push -u origin master
# Out:
# remote: Repository not found.
# fatal: repository 'https://github.com/Yashgupta-01/telecom-churn-prediction.git/' not found
